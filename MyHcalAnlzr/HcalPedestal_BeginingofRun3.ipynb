# %%
import ROOT
import os, sys
# Out:
# Welcome to JupyROOT 6.26/06

# %%
ROOT.gStyle.SetOptFit(1)
ROOT.gStyle.SetOptStat(0)
fin=ROOT.TFile.Open("/Users/longwang/Desktop/hist_CosmicsRuns_cosmic_digi.root", "READ")
fin.ls()
# Out:
# TFile**		/Users/longwang/Desktop/hist_CosmicsRuns_cosmic_digi.root
#  TFile*		/Users/longwang/Desktop/hist_CosmicsRuns_cosmic_digi.root
#   KEY: TGraph	HBMean_of_pedMean_sipmT0;1	HBMean_of_pedMean_sipmT0
#   KEY: TGraph	HBRMS_of_pedMean_sipmT0;1	HBRMS_of_pedMean_sipmT0
#   KEY: TGraph	HBMean_of_pedRMS_sipmT0;1	HBMean_of_pedRMS_sipmT0
#   KEY: TGraph	HBMean_of_pedMean_sipmT1;1	HBMean_of_pedMean_sipmT1
#   KEY: TGraph	HBRMS_of_pedMean_sipmT1;1	HBRMS_of_pedMean_sipmT1
#   KEY: TGraph	HBMean_of_pedRMS_sipmT1;1	HBMean_of_pedRMS_sipmT1
#   KEY: TGraph	HEMean_of_pedMean_sipmT0;1	HEMean_of_pedMean_sipmT0
#   KEY: TGraph	HERMS_of_pedMean_sipmT0;1	HERMS_of_pedMean_sipmT0
#   KEY: TGraph	HEMean_of_pedRMS_sipmT0;1	HEMean_of_pedRMS_sipmT0
#   KEY: TGraph	HEMean_of_pedMean_sipmT1;1	HEMean_of_pedMean_sipmT1
#   KEY: TGraph	HERMS_of_pedMean_sipmT1;1	HERMS_of_pedMean_sipmT1
#   KEY: TGraph	HEMean_of_pedRMS_sipmT1;1	HEMean_of_pedRMS_sipmT1
#   KEY: TH1F	HB_sipmT0pedMean_run358283;1	Pedestal Mean
# ...

# %%
gr1 = fin.Get("HEMean_of_pedRMS_sipmT1")
gr2 = fin.Get("HERMS_of_pedMean_sipmT1")
gr3 = fin.Get("HEMean_of_pedMean_sipmT1")
gr4 = fin.Get("HEMean_of_pedRMS_sipmT0")
gr5 = fin.Get("HERMS_of_pedMean_sipmT0")
gr6 = fin.Get("HEMean_of_pedMean_sipmT0")
gr7 = fin.Get("HBMean_of_pedRMS_sipmT1")
gr8 = fin.Get("HBRMS_of_pedMean_sipmT1")
gr9 = fin.Get("HBMean_of_pedMean_sipmT1")
gr10 = fin.Get("HBMean_of_pedRMS_sipmT0")
gr11 = fin.Get("HBRMS_of_pedMean_sipmT0")
gr12 = fin.Get("HBMean_of_pedMean_sipmT0")


c1 = ROOT.TCanvas( 'c1', 'c1', 900, 900 )
c1.cd()
gr4.SetTitle("Mean of per-channel pedestal RMS from Cosmic Runs")
gr4.GetXaxis().SetTitle("Date (Run2022)")
gr4.GetXaxis().SetDecimals()
#gr4.GetXaxis().SetMaxDigits(3)
gr4.GetYaxis().SetTitle("ADC (QIE11)")
gr4.SetMinimum(0)
gr4.SetMaximum(0.9)
gr4.SetLineColor(ROOT.kGreen)
gr4.SetLineStyle(1)
gr4.SetMarkerStyle(21)
gr4.SetMarkerColor(ROOT.kGreen)
gr4.Draw()
gr1.SetLineColor(ROOT.kGreen)
gr1.SetLineStyle(4)
gr1.SetMarkerStyle(20)
gr1.SetMarkerColor(ROOT.kGreen)
gr1.SetMarkerSize(1)
gr1.Draw("PL same")
gr7.SetLineColor(ROOT.kBlue)
gr7.SetLineStyle(4)
gr7.SetMarkerStyle(20)
gr7.SetMarkerColor(ROOT.kBlue)
gr7.Draw("PL same")
gr10.SetLineColor(ROOT.kBlue)
gr10.SetLineStyle(1)
gr10.SetMarkerStyle(21)
gr10.SetMarkerColor(ROOT.kBlue)
gr10.Draw("PL same")

legend1 = ROOT.TLegend(0.45,0.25,0.85,0.45)
legend1.AddEntry(gr1,"HE Large SiPM","pl")
legend1.AddEntry(gr4,"HE Small SiPM","pl")
legend1.AddEntry(gr7,"HB Large SiPM","pl")
legend1.AddEntry(gr10,"HB Small SiPM","pl")
legend1.Draw()

c1.Draw()
c1.SaveAs("Pedestal mean of per-channel RMS from Cosmic Runs.pdf")


c2 = ROOT.TCanvas( 'c2', 'c2', 900, 900 )
c2.cd()
gr5.SetTitle("RMS of per-channel pedestal means from Cosmic Runs")
gr5.GetXaxis().SetTitle("Date (Run2022)")
gr5.GetXaxis().SetDecimals()
gr5.GetYaxis().SetTitle("ADC (QIE11)")
gr5.SetMinimum(0)
gr5.SetMaximum(0.3)
gr5.SetLineColor(ROOT.kGreen)
gr5.SetLineStyle(1)
gr5.SetMarkerStyle(21)
gr5.SetMarkerColor(ROOT.kGreen)
gr5.Draw()
gr2.SetLineColor(ROOT.kGreen)
gr2.SetLineStyle(4)
gr2.SetMarkerStyle(20)
gr2.SetMarkerColor(ROOT.kGreen)
gr2.SetMarkerSize(1)
gr2.Draw("PL same")
gr8.SetLineColor(ROOT.kBlue)
gr8.SetLineStyle(4)
gr8.SetMarkerStyle(20)
gr8.SetMarkerColor(ROOT.kBlue)
gr8.Draw("PL same")
gr11.SetLineColor(ROOT.kBlue)
gr11.SetLineStyle(1)
gr11.SetMarkerStyle(21)
gr11.SetMarkerColor(ROOT.kBlue)
gr11.Draw("PL same")

legend2 = ROOT.TLegend(0.15,0.65,0.55,0.85)
legend2.AddEntry(gr2,"HE Large SiPM","pl")
legend2.AddEntry(gr5,"HE Small SiPM","pl")
legend2.AddEntry(gr8,"HB Large SiPM","pl")
legend2.AddEntry(gr11,"HB Small SiPM","pl")
legend2.Draw()

c2.Draw()
c2.SaveAs("Pedestal RMS of per-channel means from Cosmic Runs.pdf")


c3 = ROOT.TCanvas( 'c3', 'c3', 900, 900 )
c3.cd()
gr6.SetTitle("Mean of per-channel pedestal Mean from Cosmic Runs")
gr6.GetXaxis().SetTitle("Date (Run2022)")
gr6.GetXaxis().SetDecimals()
gr6.GetYaxis().SetTitle("ADC (QIE11)")
gr6.SetMinimum(4)
gr6.SetMaximum(7)
gr6.SetLineColor(ROOT.kGreen)
gr6.SetLineStyle(1)
gr6.SetMarkerStyle(21)
gr6.SetMarkerColor(ROOT.kGreen)
gr6.Draw()
gr3.SetLineColor(ROOT.kGreen)
gr3.SetLineStyle(4)
gr3.SetMarkerStyle(20)
gr3.SetMarkerColor(ROOT.kGreen)
gr3.SetMarkerSize(1)
gr3.Draw("PL same")
gr9.SetLineColor(ROOT.kBlue)
gr9.SetLineStyle(4)
gr9.SetMarkerStyle(20)
gr9.SetMarkerColor(ROOT.kBlue)
gr9.Draw("PL same")
gr12.SetLineColor(ROOT.kBlue)
gr12.SetLineStyle(1)
gr12.SetMarkerStyle(21)
gr12.SetMarkerColor(ROOT.kBlue)
gr12.Draw("PL same")

legend3 = ROOT.TLegend(0.45,0.25,0.85,0.45)
legend3.AddEntry(gr3,"HE Large SiPM","pl")
legend3.AddEntry(gr6,"HE Small SiPM","pl")
legend3.AddEntry(gr9,"HB Large SiPM","pl")
legend3.AddEntry(gr12,"HB Small SiPM","pl")
legend3.Draw()

c3.Draw()
c3.SaveAs("Pedestal Mean of per-channel Mean from Cosmic Runs.pdf")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Info in <TCanvas::Print>: pdf file Pedestal mean of per-channel RMS from Cosmic Runs.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2
# Info in <TCanvas::Print>: pdf file Pedestal RMS of per-channel means from Cosmic Runs.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
# Info in <TCanvas::Print>: pdf file Pedestal Mean of per-channel Mean from Cosmic Runs.pdf has been created

# %%
h1 = fin.Get("HE_sipmT0pedRMS_run358030")
h2 = fin.Get("HE_sipmT1pedRMS_run358030")
h3 = fin.Get("HB_sipmT0pedRMS_run358030")
h4 = fin.Get("HB_sipmT1pedRMS_run358030")
h5 = fin.Get("HE_sipmT0pedRMS_run358164")
h6 = fin.Get("HE_sipmT1pedRMS_run358164")
h7 = fin.Get("HE_sipmT0pedRMS_run358164")
h8 = fin.Get("HB_sipmT1pedRMS_run358164")
h9 = fin.Get("HE_sipmT0pedRMS_run358283")
h10 = fin.Get("HE_sipmT1pedRMS_run358283")
h11 = fin.Get("HB_sipmT0pedRMS_run358283")
h12 = fin.Get("HB_sipmT1pedRMS_run358283")

h9.GetXaxis().SetRangeUser(0.2,1.2)
h10.GetXaxis().SetRangeUser(0.2,1.2)
h11.GetXaxis().SetRangeUser(0.2,1.2)
h12.GetXaxis().SetRangeUser(0.2,1.2)

c = ROOT.TCanvas( 'c', 'c', 900, 900 )
c.Divide(2,2)

c.cd(1)

h9.GetXaxis().SetTitle("Pedestal RMS (QIE11 ADC)")
h9.SetTitle("HE Small SiPM Pedestal RMS")
h9.SetLineColor(ROOT.kRed)
h9.Draw()
h5.SetLineColor(ROOT.kBlue)
h5.Draw("same")
h1.SetLineColor(ROOT.kGreen)
h1.Draw("same")

legend1 = ROOT.TLegend(0.53,0.68,0.88,0.85)
legend1.AddEntry(h1,"run358030, Mean={:.3f}".format(h1.GetMean()),"l")
legend1.AddEntry(h5,"run358164, Mean={:.3f}".format(h5.GetMean()),"l")
legend1.AddEntry(h9,"run358283, Mean={:.3f}".format(h9.GetMean()),"l")
legend1.Draw()

c.cd(2)

h10.GetXaxis().SetTitle("Pedestal RMS (QIE11 ADC)")
h10.SetTitle("HE Large SiPM Pedestal RMS")
h10.SetLineColor(ROOT.kRed)
h10.Draw()
h6.SetLineColor(ROOT.kBlue)
h6.Draw("same")
h2.SetLineColor(ROOT.kGreen)
h2.Draw("same")
legend2 = ROOT.TLegend(0.53,0.68,0.88,0.85)
legend2.AddEntry(h2,"run358030, Mean={:.3f}".format(h2.GetMean()),"l")
legend2.AddEntry(h6,"run358164, Mean={:.3f}".format(h6.GetMean()),"l")
legend2.AddEntry(h10,"run358283, Mean={:.3f}".format(h10.GetMean()),"l")
legend2.Draw()

c.cd(3)

h11.GetXaxis().SetTitle("Pedestal RMS (QIE11 ADC)")
h11.SetTitle("HB Small SiPM Pedestal RMS")
h11.SetLineColor(ROOT.kRed)
h11.Draw()
h7.SetLineColor(ROOT.kBlue)
h7.Draw("same")
h3.SetLineColor(ROOT.kGreen)
h3.Draw("same")

legend3 = ROOT.TLegend(0.53,0.68,0.88,0.85)
legend3.AddEntry(h3,"run358030, Mean={:.3f}".format(h3.GetMean()),"l")
legend3.AddEntry(h7,"run358164, Mean={:.3f}".format(h7.GetMean()),"l")
legend3.AddEntry(h11,"run358283, Mean={:.3f}".format(h11.GetMean()),"l")
legend3.Draw()

c.cd(4)

h12.GetXaxis().SetTitle("Pedestal RMS (QIE11 ADC)")
h12.SetTitle("HB Large SiPM Pedestal RMS")
h12.SetLineColor(ROOT.kRed)
h12.Draw()
h8.SetLineColor(ROOT.kBlue)
h8.Draw("same")
h4.SetLineColor(ROOT.kGreen)
h4.Draw("same")
legend4 = ROOT.TLegend(0.53,0.68,0.88,0.85)
legend4.AddEntry(h4,"run358030, Mean={:.3f}".format(h4.GetMean()),"l")
legend4.AddEntry(h8,"run358164, Mean={:.3f}".format(h8.GetMean()),"l")
legend4.AddEntry(h12,"run358283, Mean={:.3f}".format(h12.GetMean()),"l")
legend4.Draw()

c.Draw()
c.SaveAs("Pedestal RMS from Cosmic Runs.pdf")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: pdf file Pedestal RMS from Cosmic Runs.pdf has been created

# %%
h1 = fin.Get("HE_sipmT0pedMean_run358030")
h2 = fin.Get("HE_sipmT1pedMean_run358030")
h3 = fin.Get("HB_sipmT0pedMean_run358030")
h4 = fin.Get("HB_sipmT1pedMean_run358030")
h5 = fin.Get("HE_sipmT0pedMean_run358164")
h6 = fin.Get("HE_sipmT1pedMean_run358164")
h7 = fin.Get("HE_sipmT0pedMean_run358164")
h8 = fin.Get("HB_sipmT1pedMean_run358164")
h9 = fin.Get("HE_sipmT0pedMean_run358283")
h10 = fin.Get("HE_sipmT1pedMean_run358283")
h11 = fin.Get("HB_sipmT0pedMean_run358283")
h12 = fin.Get("HB_sipmT1pedMean_run358283")

h1.GetXaxis().SetRangeUser(5,8)
h6.GetXaxis().SetRangeUser(5,8)
h3.GetXaxis().SetRangeUser(5,8)
h4.GetXaxis().SetRangeUser(5.5,8.5)

c = ROOT.TCanvas( 'c', 'c', 900, 900 )
c.Divide(2,2)

c.cd(1)

h1.GetXaxis().SetTitle("Pedestal Mean (QIE11 ADC)")
h1.SetTitle("HE Small SiPM Pedestal Mean")
h1.SetLineColor(ROOT.kGreen)
h1.Draw()
h5.SetLineColor(ROOT.kBlue)
h5.Draw("same")
h9.SetLineColor(ROOT.kRed)
h9.Draw("same")

legend1 = ROOT.TLegend(0.53,0.68,0.88,0.85)
legend1.AddEntry(h1,"run358030, Mean={:.3f}".format(h1.GetMean()),"l")
legend1.AddEntry(h5,"run358164, Mean={:.3f}".format(h5.GetMean()),"l")
legend1.AddEntry(h9,"run358283, Mean={:.3f}".format(h9.GetMean()),"l")
legend1.Draw()

c.cd(2)

h6.GetXaxis().SetTitle("Pedestal Mean (QIE11 ADC)")
h6.SetTitle("HE Large SiPM Pedestal Mean")
h6.SetLineColor(ROOT.kBlue)
h6.Draw()
h2.SetLineColor(ROOT.kGreen)
h2.Draw("same")
h10.SetLineColor(ROOT.kRed)
h10.Draw("same")
legend2 = ROOT.TLegend(0.53,0.68,0.88,0.85)
legend2.AddEntry(h2,"run358030, Mean={:.3f}".format(h2.GetMean()),"l")
legend2.AddEntry(h6,"run358164, Mean={:.3f}".format(h6.GetMean()),"l")
legend2.AddEntry(h10,"run358283, Mean={:.3f}".format(h10.GetMean()),"l")
legend2.Draw()

c.cd(3)

h3.GetXaxis().SetTitle("Pedestal Mean (QIE11 ADC)")
h3.SetTitle("HB Small SiPM Pedestal Mean")
h3.SetLineColor(ROOT.kGreen)
h3.SetMaximum(280)
h3.Draw()
h7.SetLineColor(ROOT.kBlue)
h7.Draw("same")
h11.SetLineColor(ROOT.kRed)
h11.Draw("same")

legend3 = ROOT.TLegend(0.53,0.68,0.88,0.85)
legend3.AddEntry(h3,"run358030, Mean={:.3f}".format(h3.GetMean()),"l")
legend3.AddEntry(h7,"run358164, Mean={:.3f}".format(h7.GetMean()),"l")
legend3.AddEntry(h11,"run358283, Mean={:.3f}".format(h11.GetMean()),"l")
legend3.Draw()

c.cd(4)

h4.GetXaxis().SetTitle("Pedestal Mean (QIE11 ADC)")
h4.SetTitle("HB Large SiPM Pedestal Mean")
h4.SetLineColor(ROOT.kGreen)
h4.SetMaximum(280)
h4.Draw()
h8.SetLineColor(ROOT.kBlue)
h8.Draw("same")
h12.SetLineColor(ROOT.kRed)
h12.Draw("same")
legend4 = ROOT.TLegend(0.53,0.68,0.88,0.85)
legend4.AddEntry(h4,"run358030, Mean={:.3f}".format(h4.GetMean()),"l")
legend4.AddEntry(h8,"run358164, Mean={:.3f}".format(h8.GetMean()),"l")
legend4.AddEntry(h12,"run358283, Mean={:.3f}".format(h12.GetMean()),"l")
legend4.Draw()

c.Draw()
c.SaveAs("Pedestal Mean from Cosmic Runs.pdf")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: pdf file Pedestal Mean from Cosmic Runs.pdf has been created
